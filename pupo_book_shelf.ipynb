# %% [markdown]
# <a href="https://colab.research.google.com/github/Brunapupo/dataset_rdf_turtle/blob/main/pupo_book_shelf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rdflib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.5 MB/s eta 0:00:00
# ...

# %%
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, DC, FOAF, XSD

# %%
g = Graph()

# %%
pupo_book_shelf = Namespace("http://pupo-bookshelf/livros#")

g.bind("pupo_book_shelf", pupo_book_shelf)

# %% [markdown]
# # **Criação de Tripla**

# %%
# Remover todas as triplas
g.remove((None, None, None))
# Out:
# <Graph identifier=Nedcbbfd1d1364516b029a0a0d11f03eb (<class 'rdflib.graph.Graph'>)>

# %%
recurso_segundos_13 = URIRef(pupo_book_shelf.segundos_13)
recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes = URIRef(pupo_book_shelf._1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes)
recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes = URIRef(pupo_book_shelf._1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes)
recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes = URIRef(pupo_book_shelf._1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes)
recurso_1984_George_Orwell = URIRef(pupo_book_shelf._1984_George_Orwell)
recurso_A_abadia_de_Northanger_Jane_Austen = URIRef(pupo_book_shelf.A_abadia_de_Northanger_Jane_Austen)
recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn = URIRef(pupo_book_shelf.A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn)
recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones = URIRef(pupo_book_shelf.A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones)
recurso_A_Dança_dos_Dragões_As_Crônicas_de_Gelo_e_Fogo_George_R_R_Martin = URIRef(pupo_book_shelf.A_Dança_dos_Dragões_As_Crônicas_de_Gelo_e_Fogo_George_R_R_Martin)
recurso_A_Fazenda_dos_animais_George_Orwell = URIRef(pupo_book_shelf.A_Fazenda_dos_animais_George_Orwell)
recurso_A_fúria_dos_reis_As_Crônicas_de_Gelo_e_Fogo_George_R_R_Martin = URIRef(pupo_book_shelf.A_fúria_dos_reis_As_Crônicas_de_Gelo_e_Fogo_George_R_R_Martin)
recurso_A_Guerra_dos_Tronos_As_Crônicas_de_Gelo_e_Fogo_George_R_R_Martin = URIRef(pupo_book_shelf.A_Guerra_dos_Tronos_As_Crônicas_de_Gelo_e_Fogo_George_R_R_Martin)
recurso_A_Guerra_que_Salvou_a_Minha_Vida_Quando_a_guerra_começa_dentro_de_casa_Kimberly_Brubaker_Bradley = URIRef(pupo_book_shelf.A_Guerra_que_Salvou_a_Minha_Vida_Quando_a_guerra_começa_dentro_de_casa_Kimberly_Brubaker_Bradley)
recurso_A_Guerra_Que_Me_Ensinou_a_Viver_O_amor_vence_a_guerra_Kimberly_Brubaker_Bradley = URIRef(pupo_book_shelf.A_Guerra_Que_Me_Ensinou_a_Viver_O_amor_vence_a_guerra_Kimberly_Brubaker_Bradley)
recurso_A_letra_escarlate_Nathaniel_Hawthorne = URIRef(pupo_book_shelf.A_letra_escarlate_Nathaniel_Hawthorne)
recurso_A_longa_Viagem_a_um_pequeno_planeta_Hostil_Becky_Chambers = URIRef(pupo_book_shelf.A_longa_Viagem_a_um_pequeno_planeta_Hostil_Becky_Chambers)
recurso_A_Menina_Submersa_Caitlín_R_Kiernan = URIRef(pupo_book_shelf.A_Menina_Submersa_Caitlín_R_Kiernan)
recurso_A_mulher_de_Branco_Wilkie_Collins = URIRef(pupo_book_shelf.A_mulher_de_Branco_Wilkie_Collins)
recurso_A_mulher_de_trinta_anos_Honoré_de_Balzac = URIRef(pupo_book_shelf.A_mulher_de_trinta_anos_Honoré_de_Balzac)
recurso_A_redoma_de_vidro_Sylvia_Plath = URIRef(pupo_book_shelf.A_redoma_de_vidro_Sylvia_Plath)
recurso_A_tormenta_de_espadas_As_Crônicas_de_Gelo_e_Fogo_George_R_R_Martin = URIRef(pupo_book_shelf.A_tormenta_de_espadas_As_Crônicas_de_Gelo_e_Fogo_George_R_R_Martin)
recurso_Agnes_Grey_Anne_Brontë = URIRef(pupo_book_shelf.Agnes_Grey_Anne_Brontë)
recurso_Alice_no_País_das_Maravilhas_Lewis_Carroll = URIRef(pupo_book_shelf.Alice_no_País_das_Maravilhas_Lewis_Carroll)
recurso_Amanhecer_Stephenie_Meyer = URIRef(pupo_book_shelf.Amanhecer_Stephenie_Meyer)
recurso_Animais_fantásticos_os_crimes_de_Grindelwald_J_K_Rowling = URIRef(pupo_book_shelf.Animais_fantásticos_os_crimes_de_Grindelwald_J_K_Rowling)
recurso_Animais_Fantásticos_e_Onde_Habitam_J_K_Rowling = URIRef(pupo_book_shelf.Animais_Fantásticos_e_Onde_Habitam_J_K_Rowling)
recurso_Anna_Karênina_Liev_Tolstói = URIRef(pupo_book_shelf.Anna_Karênina_Liev_Tolstói)
recurso_Belas_Adormecidas_Stephen_King_Owen_King = URIRef(pupo_book_shelf.Belas_Adormecidas_Stephen_King_Owen_King)
recurso_Capitães_da_areia_Jorge_Amado = URIRef(pupo_book_shelf.Capitães_da_areia_Jorge_Amado)
recurso_Comport_se_Robert_Sapolsky = URIRef(pupo_book_shelf.Comport_se_Robert_Sapolsky)
recurso_Crime_e_Castigo_Fiódor_Dostoiévski = URIRef(pupo_book_shelf.Crime_e_Castigo_Fiódor_Dostoiévski)
recurso_Crepúsculo_Stephenie_Meyer = URIRef(pupo_book_shelf.Crepúsculo_Stephenie_Meyer)
recurso_Destinado_Carina_Rissi = URIRef(pupo_book_shelf.Destinado_Carina_Rissi)
recurso_Dez_coisas_que_amo_em_você_Julia_Quinn = URIRef(pupo_book_shelf.Dez_coisas_que_amo_em_você_Julia_Quinn)
recurso_Diário_de_uma_Escrava_Rô_Mierling = URIRef(pupo_book_shelf.Diário_de_uma_Escrava_Rô_Mierling)
recurso_Donnie_Darko_Richard_Kelly = URIRef(pupo_book_shelf.Donnie_Darko_Richard_Kelly)
recurso_Drácula_Bram_Stoker = URIRef(pupo_book_shelf.Drácula_Bram_Stoker)
recurso_Dune_Frank_Herbert = URIRef(pupo_book_shelf.Dune_Frank_Herbert)
recurso_E_Viveram_Felizes_para_Sempre_Os_Bridgertons_Julia_Quinn = URIRef(pupo_book_shelf.E_Viveram_Felizes_para_Sempre_Os_Bridgertons_Julia_Quinn)
recurso_Eclipse_Stephenie_Meyer = URIRef(pupo_book_shelf.Eclipse_Stephenie_Meyer)
recurso_Ecos_Pam_Muñoz_Ryan = URIRef(pupo_book_shelf.Ecos_Pam_Muñoz_Ryan)
recurso_Edgar_Allan_Poe_Medo_Clássico_Sinta_o_medo_clássico_Edgar_Allan_Poe = URIRef(pupo_book_shelf.Edgar_Allan_Poe_Medo_Clássico_Sinta_o_medo_clássico_Edgar_Allan_Poe)
recurso_Em_Algum_Lugar_nas_Estrelas_Clare_Vanderpool = URIRef(pupo_book_shelf.Em_Algum_Lugar_nas_Estrelas_Clare_Vanderpool)
recurso_Emma_Jane_Austen = URIRef(pupo_book_shelf.Emma_Jane_Austen)
recurso_Encontrada_Carina_Rissi = URIRef(pupo_book_shelf.Encontrada_Carina_Rissi)
recurso_Exílios_e_Poemas_Cecília_Meireles = URIRef(pupo_book_shelf.Exílios_e_Poemas_Cecília_Meireles)
recurso_Filhos_de_Duna_Frank_Herbert = URIRef(pupo_book_shelf.Filhos_de_Duna_Frank_Herbert)
recurso_Fogo_e_Sangue_As_Crônicas_de_Gelo_e_Fogo_George_R_R_Martin = URIRef(pupo_book_shelf.Fogo_e_Sangue_As_Crônicas_de_Gelo_e_Fogo_George_R_R_Martin)
recurso_Frankenstein_Mary_Shelley = URIRef(pupo_book_shelf.Frankenstein_Mary_Shelley)
recurso_Geek_Love_Katherine_Dunn = URIRef(pupo_book_shelf.Geek_Love_Katherine_Dunn)
recurso_Grande_Esperanças_Charles_Dickens = URIRef(pupo_book_shelf.Grande_Esperanças_Charles_Dickens)
recurso_Grande_sertão_veredas_João_Guimarães_Rosa = URIRef(pupo_book_shelf.Grande_sertão_veredas_João_Guimarães_Rosa)
recurso_H_P_Lovecraft_Medo_Clássico_Vol_1_Cosmic_Edition_O_mestre_dos_mestres_para_todas_as_gerações_H_P_Lovecraft = URIRef(pupo_book_shelf.H_P_Lovecraft_Medo_Clássico_Vol_1_Cosmic_Edition_O_mestre_dos_mestres_para_todas_as_gerações_H_P_Lovecraft)
recurso_Harry_Potter_e_a_Câmara_Secreta_J_K_Rowling = URIRef(pupo_book_shelf.Harry_Potter_e_a_Câmara_Secreta_J_K_Rowling)
recurso_Harry_Potter_e_a_Ordem_da_Fênix_J_K_Rowling = URIRef(pupo_book_shelf.Harry_Potter_e_a_Ordem_da_Fênix_J_K_Rowling)
recurso_Harry_Potter_e_a_Pedra_Filosofal_J_K_Rowling = URIRef(pupo_book_shelf.Harry_Potter_e_a_Pedra_Filosofal_J_K_Rowling)
recurso_Harry_Potter_e_o_Cálice_de_Fogo_J_K_Rowling = URIRef(pupo_book_shelf.Harry_Potter_e_o_Cálice_de_Fogo_J_K_Rowling)
recurso_Harry_Potter_e_o_Enigma_do_Príncipe_J_K_Rowling = URIRef(pupo_book_shelf.Harry_Potter_e_o_Enigma_do_Príncipe_J_K_Rowling)
recurso_Harry_Potter_e_o_Prisioneiro_de_Azkaban_J_K_Rowling = URIRef(pupo_book_shelf.Harry_Potter_e_o_Prisioneiro_de_Azkaban_J_K_Rowling)
recurso_Harry_Potter_e_as_Relíquias_da_Morte_J_K_Rowling = URIRef(pupo_book_shelf.Harry_Potter_e_as_Relíquias_da_Morte_J_K_Rowling)
recurso_HEX_Thomas_Olde_Heuvelt = URIRef(pupo_book_shelf.HEX_Thomas_Olde_Heuvelt)
recurso_Histórias_de_um_grande_amor_N_A = URIRef(pupo_book_shelf.Histórias_de_um_grande_amor_N_A)
recurso_Howl_And_Other_Poems_04_Allen_Ginsberg = URIRef(pupo_book_shelf.Howl_And_Other_Poems_04_Allen_Ginsberg)
recurso_Indomada_P_C_Cast_Kristin_Cast = URIRef(pupo_book_shelf.Indomada_P_C_Cast_Kristin_Cast)
recurso_It_A_Coisa_Stephen_King = URIRef(pupo_book_shelf.It_A_Coisa_Stephen_King)
recurso_Jane_Eyre_Charlotte_Brontë = URIRef(pupo_book_shelf.Jane_Eyre_Charlotte_Brontë)
recurso_Judas_o_obscuro_Thomas_Hardy = URIRef(pupo_book_shelf.Judas_o_obscuro_Thomas_Hardy)
recurso_Lady_Killers_Tori_Telfer = URIRef(pupo_book_shelf.Lady_Killers_Tori_Telfer)
recurso_Lady_Susan_e_Outras_Histórias_Jane_Austen = URIRef(pupo_book_shelf.Lady_Susan_e_Outras_Histórias_Jane_Austen)
recurso_Lua_Nova_Stephenie_Meyer = URIRef(pupo_book_shelf.Lua_Nova_Stephenie_Meyer)
recurso_Macunaíma_Mário_de_Andrade = URIRef(pupo_book_shelf.Macunaíma_Mário_de_Andrade)
recurso_Madame_Bovary_Gustave_Flaubert = URIRef(pupo_book_shelf.Madame_Bovary_Gustave_Flaubert)
recurso_Malcom_X_Alex_Haley = URIRef(pupo_book_shelf.Malcom_X_Alex_Haley)
recurso_Mansfield_Park_Jane_Austen = URIRef(pupo_book_shelf.Mansfield_Park_Jane_Austen)
recurso_Meus_dias_na_livraria_Morisaki_Satoshi_Yagisawa = URIRef(pupo_book_shelf.Meus_dias_na_livraria_Morisaki_Satoshi_Yagisawa)
recurso_Messias_de_Duna_Frank_Herbert = URIRef(pupo_book_shelf.Messias_de_Duna_Frank_Herbert)
recurso_Middle_March_George_Eliot = URIRef(pupo_book_shelf.Middle_March_George_Eliot)
recurso_Moby_Dick_Herman_Melville = URIRef(pupo_book_shelf.Moby_Dick_Herman_Melville)
recurso_Mrs_Dalloway_Virginia_Woolf = URIRef(pupo_book_shelf.Mrs_Dalloway_Virginia_Woolf)
recurso_Mulheres_que_correm_com_os_lobos_Clarissa_Pinkola_Estés = URIRef(pupo_book_shelf.Mulheres_que_correm_com_os_lobos_Clarissa_Pinkola_Estés)
recurso_Mulherzinhas_Louisa_May_Alcott = URIRef(pupo_book_shelf.Mulherzinhas_Louisa_May_Alcott)
recurso_No_Coração_da_Bruxa_Genevieve_Gornichec = URIRef(pupo_book_shelf.No_Coração_da_Bruxa_Genevieve_Gornichec)
recurso_O_Alquimista_Paulo_Coelho = URIRef(pupo_book_shelf.O_Alquimista_Paulo_Coelho)
recurso_O_Arqueiro_Bernard_Cornwell = URIRef(pupo_book_shelf.O_Arqueiro_Bernard_Cornwell)
recurso_O_Castelo_animado_Diana_Wynne_Jones = URIRef(pupo_book_shelf.O_Castelo_animado_Diana_Wynne_Jones)
recurso_O_castelo_no_Ar_Diana_Wynne_Jones = URIRef(pupo_book_shelf.O_castelo_no_Ar_Diana_Wynne_Jones)
recurso_O_Colecionador_John_Fowles = URIRef(pupo_book_shelf.O_Colecionador_John_Fowles)
recurso_O_Conde_Enfeitiçado_Os_Bridgertons_Julia_Quinn = URIRef(pupo_book_shelf.O_Conde_Enfeitiçado_Os_Bridgertons_Julia_Quinn)
recurso_O_Diário_de_Anne_Frank_Anne_Frank = URIRef(pupo_book_shelf.O_Diário_de_Anne_Frank_Anne_Frank)
recurso_O_Diário_de_Miriam_Miriam_Gadelha = URIRef(pupo_book_shelf.O_Diário_de_Miriam_Miriam_Gadelha)
recurso_O_diário_de_um_Mago_Paulo_Coelho = URIRef(pupo_book_shelf.O_diário_de_um_Mago_Paulo_Coelho)
recurso_O_Duque_e_Eu_Os_Bridgertons_Julia_Quinn = URIRef(pupo_book_shelf.O_Duque_e_Eu_Os_Bridgertons_Julia_Quinn)
recurso_O_Festim_dos_Corvos_As_Crônicas_de_Gelo_e_Fogo_George_R_R_Martin = URIRef(pupo_book_shelf.O_Festim_dos_Corvos_As_Crônicas_de_Gelo_e_Fogo_George_R_R_Martin)
recurso_O_grande_Gatsby_F_Scott_Fitzgerald = URIRef(pupo_book_shelf.O_grande_Gatsby_F_Scott_Fitzgerald)
recurso_O_Hobbit_J_R_R_Tolkien = URIRef(pupo_book_shelf.O_Hobbit_J_R_R_Tolkien)
recurso_O_Médico_e_o_Monstro_Robert_Louis_Stevenson = URIRef(pupo_book_shelf.O_Médico_e_o_Monstro_Robert_Louis_Stevenson)
recurso_O_Mestre_e_Margarida_Mikhail_Bulgákov = URIRef(pupo_book_shelf.O_Mestre_e_Margarida_Mikhail_Bulgákov)
recurso_O_Morro_dos_ventos_uivantes_Emily_Brontë = URIRef(pupo_book_shelf.O_Morro_dos_ventos_uivantes_Emily_Brontë)
recurso_O_Principe_Nicolau_Maquiavel = URIRef(pupo_book_shelf.O_Principe_Nicolau_Maquiavel)
recurso_O_que_acontece_em_Londres_Julia_Quinn = URIRef(pupo_book_shelf.O_que_acontece_em_Londres_Julia_Quinn)
recurso_O_Retrato_de_Dorian_Gray_Oscar_Wilde = URIRef(pupo_book_shelf.O_Retrato_de_Dorian_Gray_Oscar_Wilde)
recurso_O_Senhor_dos_Anéis_A_Sociedade_do_Anel_J_R_R_Tolkien = URIRef(pupo_book_shelf.O_Senhor_dos_Anéis_A_Sociedade_do_Anel_J_R_R_Tolkien)
recurso_O_Senhor_dos_Anéis_As_duas_Torres_J_R_R_Tolkien = URIRef(pupo_book_shelf.O_Senhor_dos_Anéis_As_duas_Torres_J_R_R_Tolkien)
recurso_O_Senhor_dos_Anéis_O_Retorno_do_Rei_J_R_R_Tolkien = URIRef(pupo_book_shelf.O_Senhor_dos_Anéis_O_Retorno_do_Rei_J_R_R_Tolkien)
recurso_O_trono_de_Jasmin_Tasha_Suri = URIRef(pupo_book_shelf.O_trono_de_Jasmin_Tasha_Suri)
recurso_O_Visconde_que_me_Amava_Os_Bridgertons_Julia_Quinn = URIRef(pupo_book_shelf.O_Visconde_que_me_Amava_Os_Bridgertons_Julia_Quinn)
recurso_Oliver_Twist_Charles_Dickens = URIRef(pupo_book_shelf.Oliver_Twist_Charles_Dickens)
recurso_Orgulho_e_Preconceito_Jane_Austen = URIRef(pupo_book_shelf.Orgulho_e_Preconceito_Jane_Austen)
recurso_Os_Contos_de_Beedle_o_Bardo_J_K_Rowling = URIRef(pupo_book_shelf.Os_Contos_de_Beedle_o_Bardo_J_K_Rowling)
recurso_Os_Pássaros_Frank_Baker = URIRef(pupo_book_shelf.Os_Pássaros_Frank_Baker)
recurso_Os_Segredos_de_Colin_Bridgertons_Os_Bridgertons_Julia_Quinn = URIRef(pupo_book_shelf.Os_Segredos_de_Colin_Bridgertons_Os_Bridgertons_Julia_Quinn)
recurso_Paraiso_Perdido_John_Milton = URIRef(pupo_book_shelf.Paraiso_Perdido_John_Milton)
recurso_Passeio_ao_Farol_Virginia_Woolf = URIRef(pupo_book_shelf.Passeio_ao_Farol_Virginia_Woolf)
recurso_Perdida_Carina_Rissi = URIRef(pupo_book_shelf.Perdida_Carina_Rissi)
recurso_Persuasão_Jane_Austen = URIRef(pupo_book_shelf.Persuasão_Jane_Austen)
recurso_Primeiro_Amor_Ivan_Turgueniev = URIRef(pupo_book_shelf.Primeiro_Amor_Ivan_Turgueniev)
recurso_Prometida_Carina_Rissi = URIRef(pupo_book_shelf.Prometida_Carina_Rissi)
recurso_Quadribol_através_dos_séculos_J_K_Rowling = URIRef(pupo_book_shelf.Quadribol_através_dos_séculos_J_K_Rowling)
recurso_Reino_das_Bruxas_Cordélia_Funke = URIRef(pupo_book_shelf.Reino_das_Bruxas_Cordélia_Funke)
recurso_Robinson_Crusoé_Daniel_Defoe = URIRef(pupo_book_shelf.Robinson_Crusoé_Daniel_Defoe)
recurso_Romeu_e_Julieta_William_Shakespeare = URIRef(pupo_book_shelf.Romeu_e_Julieta_William_Shakespeare)
recurso_Só_os_animais_Salvam_Ceridwen_Dovey = URIRef(pupo_book_shelf.Só_os_animais_Salvam_Ceridwen_Dovey)
recurso_Temporada_de_Caça_Andrea_Camilleri = URIRef(pupo_book_shelf.Temporada_de_Caça_Andrea_Camilleri)
recurso_The_Beauty_of_Darkness_Crônicas_de_Amor_e_Ódio_Mary_E_Pearson = URIRef(pupo_book_shelf.The_Beauty_of_Darkness_Crônicas_de_Amor_e_Ódio_Mary_E_Pearson)
recurso_The_Heart_of_Betrayal_Crônicas_de_Amor_e_Ódio_Mary_E_Pearson = URIRef(pupo_book_shelf.The_Heart_of_Betrayal_Crônicas_de_Amor_e_Ódio_Mary_E_Pearson)
recurso_The_Kiss_of_Deception_Crônicas_de_Amor_e_Ódio_Mary_E_Pearson = URIRef(pupo_book_shelf.The_Kiss_of_Deception_Crônicas_de_Amor_e_Ódio_Mary_E_Pearson)
recurso_The_Warriors_Sol_Yurick = URIRef(pupo_book_shelf.The_Warriors_Sol_Yurick)
recurso_Um_Beijo_Inesquecível_Os_Bridgertons_Julia_Quinn = URIRef(pupo_book_shelf.Um_Beijo_Inesquecível_Os_Bridgertons_Julia_Quinn)
recurso_Um_Perfeito_Cavalheiro_Os_Bridgertons_Julia_Quinn = URIRef(pupo_book_shelf.Um_Perfeito_Cavalheiro_Os_Bridgertons_Julia_Quinn)
recurso_Vidas_Secas_Graciliano_Ramos = URIRef(pupo_book_shelf.Vidas_Secas_Graciliano_Ramos)
recurso_Villette_Charlotte_Brontë = URIRef(pupo_book_shelf.Villette_Charlotte_Brontë)
recurso_Virginia_Woolf_Orlando_Virginia_Woolf = URIRef(pupo_book_shelf.Virginia_Woolf_Orlando_Virginia_Woolf)

# %%
g.add((recurso_segundos_13, RDF.type, pupo_book_shelf.Livro))
g.add((recurso_segundos_13, pupo_book_shelf.tem_autor, Literal("Bel Rodrigues", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.titulo, Literal("13 Segundos", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.idade, Literal(29, datatype=XSD.integer)))
g.add((recurso_segundos_13, pupo_book_shelf.nacionalidade, Literal("Brasileira", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.quantidade_paginas, Literal(304, datatype=XSD.integer)))
g.add((recurso_segundos_13, pupo_book_shelf.editora, Literal("Galera", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.publicacao, Literal("2018-06-15", datatype=XSD.date)))
g.add((recurso_segundos_13, pupo_book_shelf.idioma, Literal("Português", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.isbn_10, Literal("8501114995", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.isbn_13, Literal("978-8501114990", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.dimensoes, Literal("20.6 x 13.4 x 2 cm", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.ranking_geral, Literal(67801, datatype=XSD.integer)))
g.add((recurso_segundos_13, pupo_book_shelf.ranking_linguas, Literal(901, datatype=XSD.integer)))
g.add((recurso_segundos_13, pupo_book_shelf.genero_literario, Literal("Drama", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.resumo, Literal("Uma história envolvente sobre superação e desafios enfrentados pela protagonista em apenas 13 segundos.", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.adaptado_para_filme, Literal(True, datatype=XSD.boolean)))
g.add((recurso_segundos_13, pupo_book_shelf.numero_de_capitulos, Literal(15, datatype=XSD.integer)))
g.add((recurso_segundos_13, pupo_book_shelf.inspiracao, Literal("Clarice Lispector", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.inspiracao, Literal("Maya Angelou", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.inspiracao, Literal("Chimamanda Ngozi Adichie", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.inspiracao, Literal("Elena Ferrante", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.inspiracao, Literal("Frida Kahlo", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.pai, Literal("José Rodrigues", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.mae, Literal("Maria Rodrigues", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.primas, Literal("Ana Silva, Carolina Santos", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.irmaos, Literal("Pedro Rodrigues", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.marido, Literal("João Pereira", datatype=XSD.string)))
g.add((recurso_segundos_13, pupo_book_shelf.pet, Literal(True, datatype=XSD.boolean)))
g.add((recurso_segundos_13, pupo_book_shelf.nome_do_pet, Literal("Luna", datatype=XSD.string)))

# A 1808 - Laurentino Gomes
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, RDF.type, pupo_book_shelf.Livro))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.tem_autor, Literal("Laurentino Gomes", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.titulo, Literal("1808: Como uma rainha louca, um príncipe medroso e uma corte corrupta enganaram Napoleão e mudaram a História de Portugal e do Brasil", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.idade, Literal(63, datatype=XSD.integer)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.nacionalidade, Literal("Brasileira", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.quantidade_paginas, Literal(408, datatype=XSD.integer)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.editora, Literal("Globo Livros", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.publicacao, Literal("2007-10-15", datatype=XSD.date)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.idioma, Literal("Português", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.isbn_10, Literal("8525044113", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.isbn_13, Literal("978-8525044110", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.dimensoes, Literal("23 x 16 x 2.4 cm", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.ranking_geral, Literal(10234, datatype=XSD.integer)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.ranking_linguas, Literal(560, datatype=XSD.integer)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.genero_literario, Literal("História", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.resumo, Literal("Este livro narra a fuga da corte portuguesa para o Brasil em 1808, abordando o impacto desse evento na história do país.", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.adaptado_para_filme, Literal(False, datatype=XSD.boolean)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.numero_de_capitulos, Literal(12, datatype=XSD.integer)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.inspiracao, Literal("João VI", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.inspiracao, Literal("Carlota Joaquina", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.inspiracao, Literal("Napoleão Bonaparte", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.inspiracao, Literal("Dom Pedro I", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.inspiracao, Literal("Marquês de Pombal", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.pai, Literal("João Gomes", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.mae, Literal("Maria Gomes", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.primas, Literal("Ana Gomes, Luísa Gomes", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.irmaos, Literal("Carlos Gomes", datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.marido, Literal(None, datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.pet, Literal(False, datatype=XSD.boolean)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.nome_do_pet, Literal(None, datatype=XSD.string)))
g.add((recurso_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes, pupo_book_shelf.amigos, Literal("Pedro Oliveira, Maria Silva, João Costa, Ana Pereira, Carlos Lima", datatype=XSD.string)))

# 1822 - Laurentino Gomes
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, RDF.type, pupo_book_shelf.Livro))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.tem_autor, Literal("Laurentino Gomes", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.titulo, Literal("1822: Como um homem sábio, uma princesa triste e um escocês louco por dinheiro ajudaram dom Pedro a criar o Brasil - um país que tinha tudo para dar errado", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.idade, Literal(64, datatype=XSD.integer)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.nacionalidade, Literal("Brasileira", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.quantidade_paginas, Literal(432, datatype=XSD.integer)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.editora, Literal("Globo Livros", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.publicacao, Literal("2010-10-15", datatype=XSD.date)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.idioma, Literal("Português", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.isbn_10, Literal("8525044121", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.isbn_13, Literal("978-8525044127", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.dimensoes, Literal("23 x 16 x 2.5 cm", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.ranking_geral, Literal(10567, datatype=XSD.integer)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.ranking_linguas, Literal(580, datatype=XSD.integer)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.genero_literario, Literal("História", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.resumo, Literal("Este livro narra os eventos que culminaram na independência do Brasil em 1822, abordando as figuras históricas envolvidas.", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.adaptado_para_filme, Literal(False, datatype=XSD.boolean)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.numero_de_capitulos, Literal(14, datatype=XSD.integer)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.inspiracao, Literal("Dom Pedro I", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.inspiracao, Literal("Leopoldina", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.inspiracao, Literal("José Bonifácio", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.inspiracao, Literal("Thomas Cochrane", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.inspiracao, Literal("Chalaça", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.pai, Literal("João Gomes", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.mae, Literal("Maria Gomes", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.primas, Literal("Ana Gomes, Luísa Gomes", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.irmaos, Literal("Carlos Gomes", datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.marido, Literal(None, datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.pet, Literal(False, datatype=XSD.boolean)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.nome_do_pet, Literal(None, datatype=XSD.string)))
g.add((recurso_1822_Como_um_homem_sábio_uma_princesa_triste_e_um_escocês_louco_por_dinheiro_ajudaram_dom_Pedro_a_criar_o_Brasil_um_país_que_tinha_tudo_para_dar_errado_Laurentino_Gomes, pupo_book_shelf.amigos, Literal("Pedro Oliveira, Maria Silva, João Costa, Ana Pereira, Carlos Lima", datatype=XSD.string)))

# 1889 - Laurentino Gomes
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, RDF.type, pupo_book_shelf.Livro))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.tem_autor, Literal("Laurentino Gomes", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.titulo, Literal("1889: Como um imperador cansado, um marechal vaidoso e um professor injustiçado contribuíram para o fim da Monarquia e a Proclamação da República no Brasil", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.idade, Literal(65, datatype=XSD.integer)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.nacionalidade, Literal("Brasileira", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.quantidade_paginas, Literal(416, datatype=XSD.integer)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.editora, Literal("Globo Livros", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.publicacao, Literal("2013-10-15", datatype=XSD.date)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.idioma, Literal("Português", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.isbn_10, Literal("852504413X", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.isbn_13, Literal("978-8525044134", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.dimensoes, Literal("23 x 16 x 2.6 cm", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.ranking_geral, Literal(10987, datatype=XSD.integer)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.ranking_linguas, Literal(590, datatype=XSD.integer)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.genero_literario, Literal("História", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.resumo, Literal("Este livro narra os eventos que levaram à Proclamação da República no Brasil em 1889, destacando as figuras chave dessa transição.", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.adaptado_para_filme, Literal(False, datatype=XSD.boolean)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.numero_de_capitulos, Literal(15, datatype=XSD.integer)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.inspiracao, Literal("Dom Pedro II", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.inspiracao, Literal("Marechal Deodoro", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.inspiracao, Literal("Benjamin Constant", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.inspiracao, Literal("Floriano Peixoto", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.inspiracao, Literal("Visconde de Ouro Preto", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.pai, Literal("João Gomes", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.mae, Literal("Maria Gomes", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.primas, Literal("Ana Gomes, Luísa Gomes", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.irmaos, Literal("Carlos Gomes", datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.marido, Literal(None, datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.pet, Literal(False, datatype=XSD.boolean)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.nome_do_pet, Literal(None, datatype=XSD.string)))
g.add((recurso_1889_Como_um_imperador_cansado_um_marechal_vaidoso_e_um_professor_injustiçado_contribuíram_para_o_fim_da_Monarquia_e_a_Proclamação_da_República_no_Brasil_Laurentino_Gomes, pupo_book_shelf.amigos, Literal("Pedro Oliveira, Maria Silva, João Costa, Ana Pereira, Carlos Lima", datatype=XSD.string)))

# 1984 - George Orwell
g.add((recurso_1984_George_Orwell, RDF.type, pupo_book_shelf.Livro))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.tem_autor, Literal("George Orwell", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.titulo, Literal("1984", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.idade, Literal(46, datatype=XSD.integer)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.nacionalidade, Literal("Britânica", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.quantidade_paginas, Literal(328, datatype=XSD.integer)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.editora, Literal("Secker & Warburg", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.publicacao, Literal("1949-06-08", datatype=XSD.date)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.idioma, Literal("Inglês", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.isbn_10, Literal("0451524934", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.isbn_13, Literal("978-0451524935", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.dimensoes, Literal("19.7 x 12.7 x 1.8 cm", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.ranking_geral, Literal(500, datatype=XSD.integer)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.ranking_linguas, Literal(50, datatype=XSD.integer)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.genero_literario, Literal("Ficção Distópica", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.resumo, Literal("Uma narrativa futurista e sombria sobre um regime totalitário que manipula a verdade e controla a vida das pessoas.", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.adaptado_para_filme, Literal(True, datatype=XSD.boolean)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.numero_de_capitulos, Literal(24, datatype=XSD.integer)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.inspiracao, Literal("A Segunda Guerra Mundial", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.inspiracao, Literal("Totalitarismo", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.inspiracao, Literal("Stalinismo", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.inspiracao, Literal("Nazismo", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.pai, Literal("Richard Blair", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.mae, Literal("Ida Blair", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.primas, Literal("Ava Orwell, Jane Orwell", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.irmaos, Literal("None", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.marido, Literal("None", datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.pet, Literal(False, datatype=XSD.boolean)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.nome_do_pet, Literal(None, datatype=XSD.string)))
g.add((recurso_1984_George_Orwell, pupo_book_shelf.amigos, Literal("John Smith, Julia Doe, Winston Brown, O'Brien White, Katharine Green", datatype=XSD.string)))

# Triplas para "A Abadia de Northanger" - Jane Austen
recurso_A_abadia_de_Northanger_Jane_Austen = URIRef(pupo_book_shelf.A_abadia_de_Northanger_Jane_Austen)
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, RDF.type, pupo_book_shelf.Livro))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.tem_autor, Literal("Jane Austen", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.titulo, Literal("A Abadia de Northanger", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.idade, Literal(41, datatype=XSD.integer)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.nacionalidade, Literal("Britânica", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.quantidade_paginas, Literal(272, datatype=XSD.integer)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.editora, Literal("Penguin Classics", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.publicacao, Literal("1817-12-01", datatype=XSD.date)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.idioma, Literal("Inglês", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.isbn_10, Literal("0140434135", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.isbn_13, Literal("978-0140434132", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.dimensoes, Literal("19.8 x 12.9 x 2 cm", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.ranking_geral, Literal(2100, datatype=XSD.integer)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.ranking_linguas, Literal(45, datatype=XSD.integer)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.genero_literario, Literal("Romance", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.resumo, Literal("Uma sátira dos romances góticos do século XVIII.", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.adaptado_para_filme, Literal(True, datatype=XSD.boolean)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.numero_de_capitulos, Literal(31, datatype=XSD.integer)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.inspiracao, Literal("Samuel Richardson", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.inspiracao, Literal("Henry Fielding", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.inspiracao, Literal("Ann Radcliffe", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.pai, Literal("George Austen", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.mae, Literal("Cassandra Leigh", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.primas, Literal("Eliza de Feuillide", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.irmaos, Literal("Cassandra Austen", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.marido, Literal("None", datatype=XSD.string)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.pet, Literal(False, datatype=XSD.boolean)))
g.add((recurso_A_abadia_de_Northanger_Jane_Austen, pupo_book_shelf.amigos, Literal("Anne Brontë, Charlotte Brontë", datatype=XSD.string)))

# Triplas para "A Caminho do Altar - Os Bridgertons" - Julia Quinn
recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn = URIRef(pupo_book_shelf.A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn)
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, RDF.type, pupo_book_shelf.Livro))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.tem_autor, Literal("Julia Quinn", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.titulo, Literal("A Caminho do Altar", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.idade, Literal(51, datatype=XSD.integer)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.nacionalidade, Literal("Americana", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.quantidade_paginas, Literal(384, datatype=XSD.integer)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.editora, Literal("Arqueiro", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.publicacao, Literal("2006-07-25", datatype=XSD.date)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.idioma, Literal("Inglês", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.isbn_10, Literal("0060740560", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.isbn_13, Literal("978-0060740561", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.dimensoes, Literal("20.3 x 13.5 x 2.8 cm", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.ranking_geral, Literal(5700, datatype=XSD.integer)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.ranking_linguas, Literal(70, datatype=XSD.integer)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.genero_literario, Literal("Romance", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.resumo, Literal("Uma história encantadora que combina humor e romance.", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.adaptado_para_filme, Literal(True, datatype=XSD.boolean)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.numero_de_capitulos, Literal(19, datatype=XSD.integer)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.inspiracao, Literal("Jane Austen", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.inspiracao, Literal("Charlotte Brontë", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.inspiracao, Literal("Sarah MacLean", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.pai, Literal("Stephen Cotler", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.mae, Literal("Jane Cotler", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.primas, Literal("None", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.irmaos, Literal("None", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.marido, Literal("Paul Pottinger", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.pet, Literal(True, datatype=XSD.boolean)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.nome_do_pet, Literal("Clyde", datatype=XSD.string)))
g.add((recurso_A_Caminho_do_Altar_Os_Bridgertons_Julia_Quinn, pupo_book_shelf.amigos, Literal("Sarah MacLean", datatype=XSD.string)))

# Triplas para "A Casa dos Muitos Caminhos" - Diana Wynne Jones
recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones = URIRef(pupo_book_shelf.A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones)
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, RDF.type, pupo_book_shelf.Livro))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.tem_autor, Literal("Diana Wynne Jones", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.titulo, Literal("A Casa dos Muitos Caminhos", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.idade, Literal(74, datatype=XSD.integer)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.nacionalidade, Literal("Britânica", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.quantidade_paginas, Literal(432, datatype=XSD.integer)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.editora, Literal("HarperCollins", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.publicacao, Literal("2008-04-07", datatype=XSD.date)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.idioma, Literal("Inglês", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.isbn_10, Literal("0007275682", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.isbn_13, Literal("978-0007275687", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.dimensoes, Literal("19.7 x 13 x 2.7 cm", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.ranking_geral, Literal(3200, datatype=XSD.integer)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.ranking_linguas, Literal(55, datatype=XSD.integer)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.genero_literario, Literal("Fantasia", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.resumo, Literal("Uma continuação mágica das aventuras de Howl e Sophie.", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.adaptado_para_filme, Literal(False, datatype=XSD.boolean)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.numero_de_capitulos, Literal(21, datatype=XSD.integer)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.inspiracao, Literal("J.R.R. Tolkien", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.inspiracao, Literal("C.S. Lewis", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.inspiracao, Literal("Ursula K. Le Guin", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.pai, Literal("Richard Jones", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.mae, Literal("Marjorie Jones", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.primas, Literal("None", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.irmaos, Literal("Ursula Jones", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.marido, Literal("John Burrow", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.pet, Literal(True, datatype=XSD.boolean)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.nome_do_pet, Literal("Sam", datatype=XSD.string)))
g.add((recurso_A_Casa_dos_Muitos_Caminhos_Diana_Wynne_Jones, pupo_book_shelf.amigos, Literal("Neil Gaiman", datatype=XSD.string)))

# Triplas para "A Dança dos Dragões - As Crônicas de Gelo e Fogo" - George R. R. Martin
recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin = URIRef(pupo_book_shelf.A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin)
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, RDF.type, pupo_book_shelf.Livro))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.tem_autor, Literal("George R. R. Martin", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.titulo, Literal("A Dança dos Dragões", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.idade, Literal(72, datatype=XSD.integer)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.nacionalidade, Literal("Americana", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.quantidade_paginas, Literal(1056, datatype=XSD.integer)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.editora, Literal("Bantam Books", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.publicacao, Literal("2011-07-12", datatype=XSD.date)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.idioma, Literal("Inglês", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.isbn_10, Literal("0553801473", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.isbn_13, Literal("978-0553801477", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.dimensoes, Literal("24.1 x 16.3 x 6 cm", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.ranking_geral, Literal(800, datatype=XSD.integer)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.ranking_linguas, Literal(85, datatype=XSD.integer)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.genero_literario, Literal("Fantasia", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.resumo, Literal("O quinto volume da série As Crônicas de Gelo e Fogo, uma saga épica sobre poder e intrigas em um mundo de fantasia.", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.adaptado_para_filme, Literal(True, datatype=XSD.boolean)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.numero_de_capitulos, Literal(73, datatype=XSD.integer)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.inspiracao, Literal("J.R.R. Tolkien", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.inspiracao, Literal("Maurice Druon", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.inspiracao, Literal("Jack Vance", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.pai, Literal("Raymond Collins Martin", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.mae, Literal("Margaret Brady Martin", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.primas, Literal("None", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.irmaos, Literal("Darleen Martin, Janet Martin", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.marido, Literal("Parris McBride", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.pet, Literal(True, datatype=XSD.boolean)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.nome_do_pet, Literal("Tilion", datatype=XSD.string)))
g.add((recurso_A_Danca_dos_Dragoes_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.amigos, Literal("Robert Jordan, Neil Gaiman", datatype=XSD.string)))

# Triplas para "A Fazenda dos Animais" - George Orwell
recurso_A_Fazenda_dos_Animais_George_Orwell = URIRef(pupo_book_shelf.A_Fazenda_dos_Animais_George_Orwell)
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, RDF.type, pupo_book_shelf.Livro))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.tem_autor, Literal("George Orwell", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.titulo, Literal("A Fazenda dos Animais", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.idade, Literal(46, datatype=XSD.integer)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.nacionalidade, Literal("Britânica", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.quantidade_paginas, Literal(112, datatype=XSD.integer)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.editora, Literal("Secker & Warburg", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.publicacao, Literal("1945-08-17", datatype=XSD.date)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.idioma, Literal("Inglês", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.isbn_10, Literal("0452284244", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.isbn_13, Literal("978-0452284240", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.dimensoes, Literal("19.6 x 12.9 x 1.2 cm", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.ranking_geral, Literal(300, datatype=XSD.integer)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.ranking_linguas, Literal(30, datatype=XSD.integer)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.genero_literario, Literal("Fábula", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.resumo, Literal("Uma alegoria sobre a revolução russa e o perigo de regimes totalitários.", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.adaptado_para_filme, Literal(True, datatype=XSD.boolean)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.numero_de_capitulos, Literal(10, datatype=XSD.integer)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.inspiracao, Literal("Revolução Russa", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.inspiracao, Literal("Karl Marx", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.inspiracao, Literal("Stalinismo", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.inspiracao, Literal("Totalitarismo", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.pai, Literal("Richard Blair", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.mae, Literal("Ida Blair", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.primas, Literal("Ava Orwell, Jane Orwell", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.irmaos, Literal("None", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.marido, Literal("None", datatype=XSD.string)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.pet, Literal(False, datatype=XSD.boolean)))
g.add((recurso_A_Fazenda_dos_Animais_George_Orwell, pupo_book_shelf.amigos, Literal("Arthur Koestler, Malcolm Muggeridge", datatype=XSD.string)))

# Triplas para "A Fúria dos Reis - As Crônicas de Gelo e Fogo" - George R. R. Martin
recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin = URIRef(pupo_book_shelf.A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin)
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, RDF.type, pupo_book_shelf.Livro))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.tem_autor, Literal("George R. R. Martin", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.titulo, Literal("A Fúria dos Reis", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.idade, Literal(73, datatype=XSD.integer)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.nacionalidade, Literal("Americana", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.quantidade_paginas, Literal(969, datatype=XSD.integer)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.editora, Literal("Bantam Books", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.publicacao, Literal("1999-02-02", datatype=XSD.date)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.idioma, Literal("Inglês", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.isbn_10, Literal("0553579908", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.isbn_13, Literal("978-0553579901", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.dimensoes, Literal("23.5 x 15.9 x 5.1 cm", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.ranking_geral, Literal(1500, datatype=XSD.integer)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.ranking_linguas, Literal(80, datatype=XSD.integer)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.genero_literario, Literal("Fantasia", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.resumo, Literal("O segundo livro da série épica As Crônicas de Gelo e Fogo, repleto de batalhas e intrigas políticas.", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.adaptado_para_filme, Literal(True, datatype=XSD.boolean)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.numero_de_capitulos, Literal(70, datatype=XSD.integer)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.inspiracao, Literal("J.R.R. Tolkien", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.inspiracao, Literal("Maurice Druon", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.inspiracao, Literal("Jack Vance", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.pai, Literal("Raymond Collins Martin", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.mae, Literal("Margaret Brady Martin", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.primas, Literal("None", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.irmaos, Literal("Darleen Martin, Janet Martin", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.marido, Literal("Parris McBride", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.pet, Literal(True, datatype=XSD.boolean)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.nome_do_pet, Literal("Tilion", datatype=XSD.string)))
g.add((recurso_A_Furia_dos_Reis_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.amigos, Literal("Robert Jordan, Neil Gaiman", datatype=XSD.string)))

# Triplas para "A Guerra dos Tronos - As Crônicas de Gelo e Fogo" - George R. R. Martin
recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin = URIRef(pupo_book_shelf.A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin)
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, RDF.type, pupo_book_shelf.Livro))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.tem_autor, Literal("George R. R. Martin", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.titulo, Literal("A Guerra dos Tronos", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.idade, Literal(73, datatype=XSD.integer)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.nacionalidade, Literal("Americana", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.quantidade_paginas, Literal(694, datatype=XSD.integer)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.editora, Literal("Bantam Books", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.publicacao, Literal("1996-08-06", datatype=XSD.date)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.idioma, Literal("Inglês", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.isbn_10, Literal("0553103547", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.isbn_13, Literal("978-0553103540", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.dimensoes, Literal("24.2 x 16.4 x 5.2 cm", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.ranking_geral, Literal(1200, datatype=XSD.integer)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.ranking_linguas, Literal(75, datatype=XSD.integer)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.genero_literario, Literal("Fantasia", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.resumo, Literal("O primeiro livro da épica série As Crônicas de Gelo e Fogo, que define o palco para as intrigas e batalhas pelo Trono de Ferro.", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.adaptado_para_filme, Literal(True, datatype=XSD.boolean)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.numero_de_capitulos, Literal(72, datatype=XSD.integer)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.inspiracao, Literal("J.R.R. Tolkien", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.inspiracao, Literal("Maurice Druon", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.inspiracao, Literal("Jack Vance", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.pai, Literal("Raymond Collins Martin", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.mae, Literal("Margaret Brady Martin", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.primas, Literal("None", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.irmaos, Literal("Darleen Martin, Janet Martin", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.marido, Literal("Parris McBride", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.pet, Literal(True, datatype=XSD.boolean)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.nome_do_pet, Literal("Tilion", datatype=XSD.string)))
g.add((recurso_A_Guerra_dos_Tronos_As_Cronicas_de_Gelo_e_Fogo_George_R_R_Martin, pupo_book_shelf.amigos, Literal("Robert Jordan, Neil Gaiman", datatype=XSD.string)))

# Triplas para "A Guerra que Salvou a Minha Vida" - Kimberly Brubaker Bradley
recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley = URIRef(pupo_book_shelf.A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley)
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, RDF.type, pupo_book_shelf.Livro))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.tem_autor, Literal("Kimberly Brubaker Bradley", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.titulo, Literal("A Guerra que Salvou a Minha Vida", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.idade, Literal(53, datatype=XSD.integer)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.nacionalidade, Literal("Americana", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.quantidade_paginas, Literal(316, datatype=XSD.integer)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.editora, Literal("Dial Books", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.publicacao, Literal("2015-01-08", datatype=XSD.date)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.idioma, Literal("Inglês", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.isbn_10, Literal("0803740816", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.isbn_13, Literal("978-0803740815", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.dimensoes, Literal("20.3 x 14.0 x 3.0 cm", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.ranking_geral, Literal(500, datatype=XSD.integer)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.ranking_linguas, Literal(60, datatype=XSD.integer)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.genero_literario, Literal("Ficção Histórica", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.resumo, Literal("Uma emocionante história de sobrevivência e superação durante a Segunda Guerra Mundial.", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.adaptado_para_filme, Literal(False, datatype=XSD.boolean)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.numero_de_capitulos, Literal(29, datatype=XSD.integer)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.inspiracao, Literal("Segunda Guerra Mundial", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.inspiracao, Literal("História de refugiados", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.inspiracao, Literal("Sobrevivência", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.pai, Literal("Robert Bradley", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.mae, Literal("Elizabeth Bradley", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.primas, Literal("None", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.irmaos, Literal("None", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.marido, Literal("Tom Bradley", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.pet, Literal(True, datatype=XSD.boolean)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.nome_do_pet, Literal("Max", datatype=XSD.string)))
g.add((recurso_A_Guerra_que_Salvou_a_Minha_Vida_Kimberly_Brubaker_Bradley, pupo_book_shelf.amigos, Literal("Judy Blume, Katherine Paterson", datatype=XSD.string)))


print("#######################################################################\n" +
      "################## Pupo bookshelf\n" +
      "#######################################################################\n\n")

print(g.serialize(format="turtle"))
# Out:
# #######################################################################
# ################## Pupo bookshelf
# #######################################################################
#
#
# @prefix pupo_book_shelf: <http://pupo-bookshelf/livros#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# pupo_book_shelf:_1808_Como_uma_rainha_louca_um_príncipe_medroso_e_uma_corte_corrupta_enganaram_Napoleão_e_mudaram_a_História_de_Portugal_e_do_Brasil_Laurentino_Gomes a pupo_book_shelf:Livro ;
#     pupo_book_shelf:adaptado_para_filme false ;
#     pupo_book_shelf:amigos "Pedro Oliveira, Maria Silva, João Costa, Ana Pereira, Carlos Lima"^^xsd:string ;
#     pupo_book_shelf:dimensoes "23 x 16 x 2.4 cm"^^xsd:string ;
#     pupo_book_shelf:editora "Globo Livros"^^xsd:string ;
#     pupo_book_shelf:genero_literario "História"^^xsd:string ;
#     pupo_book_shelf:idade 63 ;
#     pupo_book_shelf:idioma "Português"^^xsd:string ;
#     pupo_book_shelf:inspiracao "Carlota Joaquina"^^xsd:string,
# ...
