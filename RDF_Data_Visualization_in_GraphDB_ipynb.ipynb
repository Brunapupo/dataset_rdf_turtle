# %% [markdown]
# <a href="https://colab.research.google.com/github/Brunapupo/dataset_rdf_turtle/blob/main/RDF_Data_Visualization_in_GraphDB_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rdflib
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, DC, FOAF, XSD
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.4 MB/s eta 0:00:00
# ...

# %%
g = Graph()

# %%
# Remover todas as triplas
g.remove((None, None, None))
# Out:
# <Graph identifier=N8d613a59d0904d749476843f514e9755 (<class 'rdflib.graph.Graph'>)>

# %%
# Criar um gráfico RDF
g = Graph()

# Definir o namespace biblioteca_pupo para todos os recursos
biblioteca_pupo = Namespace("http://biblioteca_pupo/livros#")

# Adicionar o namespace ao gráfico
g.bind("biblioteca_pupo", biblioteca_pupo)

#recursos globais
#----------------------------------------------------------------------------------------------------------------------
recurso_biblioteca = URIRef(biblioteca_pupo["Biblioteca_da_Pupo"])
recurso_genero_romance = URIRef(biblioteca_pupo["Romance"])
recurso_editora_penguin = URIRef(biblioteca_pupo["Penguin_Classics"])
#----------------------------------------------------------------------------------------------------------------------


# Bel Rodrigues
#----------------------------------------------------------------------------------------------------------------------
recurso_livro_13s = URIRef(biblioteca_pupo["13_Segundos"])
recurso_autora_bel = URIRef(biblioteca_pupo["Autora_Bel_Rodrigues"])

# 13 Segundos
g.add((recurso_livro_13s, RDF.type, biblioteca_pupo.Livro))
g.add((recurso_livro_orgulho, RDF.type, biblioteca_pupo.recurso_autora_bel))
g.add((recurso_livro_13s, biblioteca_pupo.pertence, recurso_biblioteca))
g.add((recurso_livro_13s, biblioteca_pupo.genero_literario, recurso_genero_romance))
g.add((recurso_livro_13s, biblioteca_pupo.idade, Literal(29, datatype=XSD.integer)))
g.add((recurso_livro_13s, biblioteca_pupo.nacionalidade, Literal("Brasileira", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.email, URIRef("bel_rodrigues@gmail.com")))
g.add((recurso_livro_13s, biblioteca_pupo.quantidade_paginas, Literal(304, datatype=XSD.integer)))
g.add((recurso_livro_13s, biblioteca_pupo.editora, Literal("Arqueiro", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.publicacao, Literal("2018-06-15", datatype=XSD.date)))
g.add((recurso_livro_13s, biblioteca_pupo.idioma, Literal("Português", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.isbn_10, Literal("8501114995", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.isbn_13, Literal("978-8501114990", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.dimensoes, Literal("20.6 x 13.4 x 2 cm", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.ranking_geral, Literal(67801, datatype=XSD.integer)))
g.add((recurso_livro_13s, biblioteca_pupo.ranking_linguas, Literal(901, datatype=XSD.integer)))
g.add((recurso_livro_13s, biblioteca_pupo.genero_literario, Literal("Romance", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.resumo, Literal("Uma história envolvente sobre superação e desafios enfrentados pela protagonista em apenas 13 segundos.", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.adaptado_para_filme, Literal(True, datatype=XSD.boolean)))
g.add((recurso_livro_13s, biblioteca_pupo.numero_de_capitulos, Literal(15, datatype=XSD.integer)))
g.add((recurso_livro_13s, biblioteca_pupo.inspiracao, Literal("Clarice Lispector", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.inspiracao, Literal("Maya Angelou", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.inspiracao, Literal("Chimamanda Ngozi Adichie", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.inspiracao, Literal("Elena Ferrante", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.inspiracao, Literal("Frida Kahlo", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.pai, Literal("José Rodrigues", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.mae, Literal("Maria Rodrigues", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.primas, Literal("Ana Silva, Carolina Santos", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.irmaos, Literal("Pedro Rodrigues", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.marido, Literal("João Pereira", datatype=XSD.string)))
g.add((recurso_livro_13s, biblioteca_pupo.pet, Literal(True, datatype=XSD.boolean)))
g.add((recurso_livro_13s, biblioteca_pupo.nome_do_pet, Literal("Luna", datatype=XSD.string)))


# Jane Austen
#----------------------------------------------------------------------------------------------------------------------
recurso_autora_jane = URIRef(biblioteca_pupo["Jane_Austen"])
recurso_livro_orgulho = URIRef(biblioteca_pupo["Orgulho_e_Preconceito"])
recurso_livro_emma = URIRef(biblioteca_pupo["Emma"])
recurso_livro_persuasao = URIRef(biblioteca_pupo["Persuasao"])
recurso_livro_lady = URIRef(biblioteca_pupo["Lady_Susan"])
recurso_autora_anne_bronte = URIRef(biblioteca_pupo["Anne_Bronte"])
recurso_autora_charlotte_bronte = URIRef(biblioteca_pupo["Charlotte_Bronte"])
recurso_autora_thomas_hardy = URIRef(biblioteca_pupo["Thomas_Hardy"])

# Adicionar as informações sobre a autora "Jane Austen"
g.add((recurso_autora_jane, RDF.type, biblioteca_pupo.Autora))
g.add((recurso_autora_jane, biblioteca_pupo.nome_completo, Literal("Jane Austen", datatype=XSD.string)))
g.add((recurso_autora_jane, biblioteca_pupo.data_de_nascimento, Literal("1775-12-16", datatype=XSD.date)))
g.add((recurso_autora_jane, biblioteca_pupo.data_de_falecimento, Literal("1817-07-18", datatype=XSD.date)))
g.add((recurso_autora_jane, biblioteca_pupo.nacionalidade, Literal("Britânica", datatype=XSD.string)))
g.add((recurso_autora_jane, biblioteca_pupo.genero, Literal("Feminino", datatype=XSD.string)))
g.add((recurso_autora_jane, biblioteca_pupo.biografia, Literal("Jane Austen foi uma escritora inglesa conhecida por seus romances que retratam a vida da classe média inglesa do final do século XVIII e início do século XIX.", datatype=XSD.string)))
g.add((recurso_autora_jane, biblioteca_pupo.amiga, recurso_autora_anne_bronte))
g.add((recurso_autora_jane, biblioteca_pupo.amiga, recurso_autora_charlotte_bronte))
g.add((recurso_autora_jane, biblioteca_pupo.amiga, recurso_autora_thomas_hardy))
g.add((recurso_autora_jane, biblioteca_pupo.inspiracao, Literal("Samuel Richardson", datatype=XSD.string)))
g.add((recurso_autora_jane, biblioteca_pupo.inspiracao, Literal("Henry Fielding", datatype=XSD.string)))
g.add((recurso_autora_jane, biblioteca_pupo.inspiracao, Literal("Frances Burney", datatype=XSD.string)))
g.add((recurso_autora_jane, biblioteca_pupo.pai, Literal("George Austen", datatype=XSD.string)))
g.add((recurso_autora_jane, biblioteca_pupo.mae, Literal("Cassandra Leigh", datatype=XSD.string)))
g.add((recurso_autora_jane, biblioteca_pupo.irma, Literal("Cassandra Austen", datatype=XSD.string)))
g.add((recurso_autora_jane, biblioteca_pupo.irmao, Literal("Edward Austen", datatype=XSD.string)))
g.add((recurso_autora_jane, biblioteca_pupo.irmao, Literal("Henry Austen", datatype=XSD.string)))

#Orgulho e Preconceito
g.add((recurso_editora_penguin, RDF.type, biblioteca_pupo.Editora))
g.add((recurso_livro_orgulho, RDF.type, biblioteca_pupo.Livro))
g.add((recurso_livro_orgulho, biblioteca_pupo.autora, recurso_autora_jane))
g.add((recurso_livro_orgulho, biblioteca_pupo.titulo, Literal("Orgulho e Preconceito", datatype=XSD.string)))
g.add((recurso_livro_orgulho, biblioteca_pupo.publicacao, Literal("1813-01-28", datatype=XSD.date)))
g.add((recurso_livro_orgulho, biblioteca_pupo.quantidade_paginas, Literal(432, datatype=XSD.integer)))
g.add((recurso_livro_orgulho, biblioteca_pupo.editora, recurso_editora_penguin))
g.add((recurso_livro_orgulho, biblioteca_pupo.resumo, Literal("A história de Elizabeth Bennet lidando com questões de moralidade, educação e casamento na Inglaterra do século 19.", datatype=XSD.string)))
g.add((recurso_livro_orgulho, biblioteca_pupo.genero_literario, recurso_genero_romance))
g.add((recurso_livro_orgulho, biblioteca_pupo.isbn_10, Literal("0141439513", datatype=XSD.string)))
g.add((recurso_livro_orgulho, biblioteca_pupo.isbn_13, Literal("978-0141439518", datatype=XSD.string)))

# Emma
g.add((recurso_livro_emma, RDF.type, biblioteca_pupo.Livro))
g.add((recurso_livro_emma, biblioteca_pupo.autora, recurso_autora_jane))
g.add((recurso_livro_emma, biblioteca_pupo.titulo, Literal("Emma", datatype=XSD.string)))
g.add((recurso_livro_emma, biblioteca_pupo.publicacao, Literal("1815-12-25", datatype=XSD.date)))
g.add((recurso_livro_emma, biblioteca_pupo.quantidade_paginas, Literal(474, datatype=XSD.integer)))
g.add((recurso_livro_emma, biblioteca_pupo.editora, recurso_editora_penguin))
g.add((recurso_livro_emma, biblioteca_pupo.resumo, Literal("A história de uma jovem chamada Emma Woodhouse e sua jornada de autoconhecimento e descobertas no que diz respeito ao casamento.", datatype=XSD.string)))
g.add((recurso_livro_emma, biblioteca_pupo.genero_literario, recurso_genero_romance))

# Persuasão
g.add((recurso_livro_persuasao, RDF.type, biblioteca_pupo.Livro))
g.add((recurso_livro_persuasao, biblioteca_pupo.autora, recurso_autora_jane))
g.add((recurso_livro_persuasao, biblioteca_pupo.titulo, Literal("Persuasão", datatype=XSD.string)))
g.add((recurso_livro_persuasao, biblioteca_pupo.publicacao, Literal("1817", datatype=XSD.date)))
g.add((recurso_livro_persuasao, biblioteca_pupo.quantidade_paginas, Literal(272, datatype=XSD.integer)))
g.add((recurso_livro_persuasao, biblioteca_pupo.editora, recurso_editora_penguin))
g.add((recurso_livro_persuasao, biblioteca_pupo.resumo, Literal("A história de Anne Elliot, que tenta reconquistar seu amor perdido, o capitão Wentworth, em uma sociedade rígida de classe.", datatype=XSD.string)))
g.add((recurso_livro_persuasao, biblioteca_pupo.genero_literario, recurso_genero_romance))

# Lady Susan
g.add((recurso_livro_lady, RDF.type, biblioteca_pupo.Livro))
g.add((recurso_livro_lady, biblioteca_pupo.autora, recurso_autora_jane))
g.add((recurso_livro_lady, biblioteca_pupo.titulo, Literal("Lady Susan", datatype=XSD.string)))
g.add((recurso_livro_lady, biblioteca_pupo.publicacao, Literal("1871", datatype=XSD.date)))
g.add((recurso_livro_lady, biblioteca_pupo.quantidade_paginas, Literal(128, datatype=XSD.integer)))
g.add((recurso_livro_lady, biblioteca_pupo.editora, recurso_editora_penguin))
g.add((recurso_livro_lady, biblioteca_pupo.resumo, Literal("Lady Susan narra as artimanhas de uma viúva manipuladora para garantir seu lugar na sociedade.", datatype=XSD.string)))
g.add((recurso_livro_lady, biblioteca_pupo.genero_literario, recurso_genero_romance))

#----------------------------------------------------------------------------------------------------------------------


# As irmãs Brontë
#---------------------------------------------------------------------------------------------------------------------
# Anne Brontë
recurso_autora_anne_bronte = URIRef(biblioteca_pupo["Anne_Bronte"])
recurso_livro_inquilina = URIRef(biblioteca_pupo["A_inquilina_de_Wildfell_Hall"])
recurso_livro_agnes = URIRef(biblioteca_pupo["Agnes_Grey"])
# Emily Brontë
recurso_autora_emily_bronte = URIRef(biblioteca_pupo["Emily_Bronte"])
recurso_morro_uivantes = URIRef(biblioteca_pupo["O_Morro_dos_Ventos_Uivantes"])
# Charlotte Brontë
recurso_autora_charlotte_bronte = URIRef(biblioteca_pupo["Charlotte_Bronte"])
recurso_jane_eyre = URIRef(biblioteca_pupo["Jane_Eyre"])
recurso_villette = URIRef(biblioteca_pupo["Villette"])

# Anne Brontë
#---------------------------------------------------------------------------------------------------------------------
g.add((recurso_autora_anne_bronte, RDF.type, biblioteca_pupo.Autora))
g.add((recurso_autora_anne_bronte, biblioteca_pupo.nome_completo, Literal("Anne Brontë", datatype=XSD.string)))
g.add((recurso_autora_anne_bronte, biblioteca_pupo.data_de_nascimento, Literal("1820-01-17", datatype=XSD.date)))
g.add((recurso_autora_anne_bronte, biblioteca_pupo.data_de_falecimento, Literal("1849-05-28", datatype=XSD.date)))
g.add((recurso_autora_anne_bronte, biblioteca_pupo.nacionalidade, Literal("Britânica", datatype=XSD.string)))
g.add((recurso_autora_anne_bronte, biblioteca_pupo.genero, Literal("Feminino", datatype=XSD.string)))
g.add((recurso_autora_anne_bronte, biblioteca_pupo.biografia, Literal("Anne Brontë foi uma escritora inglesa, irmã de Charlotte e Emily Brontë, conhecida por seu trabalho realista e crítico, retratando a vida de mulheres na Inglaterra vitoriana.", datatype=XSD.string)))
g.add((recurso_autora_anne_bronte, biblioteca_pupo.irma, recurso_autora_emily_bronte))
g.add((recurso_autora_anne_bronte, biblioteca_pupo.irma, recurso_autora_charlotte_bronte))
g.add((recurso_autora_anne_bronte, biblioteca_pupo.amiga, recurso_autora_jane))
g.add((recurso_autora_anne_bronte, biblioteca_pupo.inspiracao, Literal("Charlotte Brontë", datatype=XSD.string)))
g.add((recurso_autora_anne_bronte, biblioteca_pupo.inspiracao, Literal("Emily Brontë", datatype=XSD.string)))
g.add((recurso_autora_anne_bronte, biblioteca_pupo.inspiracao, Literal("Jane Austen", datatype=XSD.string)))
g.add((recurso_autora_anne_bronte, biblioteca_pupo.pai, Literal("Patrick Brontë", datatype=XSD.string)))
g.add((recurso_autora_anne_bronte, biblioteca_pupo.mae, Literal("Maria Branwell Brontë", datatype=XSD.string)))

# A inquilina de Wildfell Hall
g.add((recurso_livro_inquilina, RDF.type, biblioteca_pupo.Livro))
g.add((recurso_livro_inquilina, biblioteca_pupo.autora, recurso_autora_anne_bronte))
g.add((recurso_livro_inquilina, biblioteca_pupo.titulo, Literal("A Inquilina de Wildfell Hall", datatype=XSD.string)))
g.add((recurso_livro_inquilina, biblioteca_pupo.publicacao, Literal("1848-06-01", datatype=XSD.date)))
g.add((recurso_livro_inquilina, biblioteca_pupo.quantidade_paginas, Literal(448, datatype=XSD.integer)))
g.add((recurso_livro_inquilina, biblioteca_pupo.editora, recurso_editora_penguin))
g.add((recurso_livro_inquilina, biblioteca_pupo.resumo, Literal("A Inquilina de Wildfell Hall é um dos primeiros romances feministas, focado em questões como o abuso conjugal e o poder das mulheres de se libertarem de relacionamentos tóxicos.", datatype=XSD.string)))
g.add((recurso_livro_inquilina, biblioteca_pupo.genero_literario, recurso_genero_romance))

# Livro Agnes Grey
g.add((recurso_livro_agnes, RDF.type, biblioteca_pupo.Livro))
g.add((recurso_livro_agnes, biblioteca_pupo.autora, recurso_autora_anne_bronte))
g.add((recurso_livro_agnes, biblioteca_pupo.titulo, Literal("Agnes Grey", datatype=XSD.string)))
g.add((recurso_livro_agnes, biblioteca_pupo.publicacao, Literal("1847", datatype=XSD.date)))
g.add((recurso_livro_agnes, biblioteca_pupo.quantidade_paginas, Literal(368, datatype=XSD.integer)))
g.add((recurso_livro_agnes, biblioteca_pupo.editora, recurso_editora_penguin))
g.add((recurso_livro_agnes, biblioteca_pupo.resumo, Literal("Agnes Grey narra a vida de uma jovem governanta em casas de famílias ricas na Inglaterra, enfrentando dificuldades e injustiças em seu trabalho.", datatype=XSD.string)))
g.add((recurso_livro_agnes, biblioteca_pupo.genero_literario, recurso_genero_romance))
g.add((recurso_autora_emily_bronte, biblioteca_pupo.irma, recurso_autora_anne_bronte))
g.add((recurso_autora_charlotte_bronte, biblioteca_pupo.irma, recurso_autora_anne_bronte))

#Emily Brontë
#----------------------------------------------------------------------------------------------------------------------
g.add((recurso_autora_emily_bronte, RDF.type, biblioteca_pupo.Autora))
g.add((recurso_autora_emily_bronte, biblioteca_pupo.nome_completo, Literal("Emily Brontë", datatype=XSD.string)))
g.add((recurso_autora_emily_bronte, biblioteca_pupo.data_de_nascimento, Literal("1818-07-30", datatype=XSD.date)))
g.add((recurso_autora_emily_bronte, biblioteca_pupo.data_de_falecimento, Literal("1848-12-19", datatype=XSD.date)))
g.add((recurso_autora_emily_bronte, biblioteca_pupo.nacionalidade, Literal("Britânica", datatype=XSD.string)))
g.add((recurso_autora_emily_bronte, biblioteca_pupo.genero, Literal("Feminino", datatype=XSD.string)))
g.add((recurso_autora_emily_bronte, biblioteca_pupo.biografia, Literal("Emily Brontë foi uma romancista e poetisa inglesa, autora do clássico 'O Morro dos Ventos Uivantes'. Sua única obra em prosa se tornou um dos grandes clássicos da literatura mundial.", datatype=XSD.string)))
g.add((recurso_autora_emily_bronte, biblioteca_pupo.irma, recurso_autora_anne_bronte))
g.add((recurso_autora_emily_bronte, biblioteca_pupo.irma, recurso_autora_charlotte_bronte))
g.add((recurso_autora_emily_bronte, biblioteca_pupo.amiga, recurso_autora_jane))
g.add((recurso_autora_emily_bronte, biblioteca_pupo.inspiracao, Literal("Walter Scott", datatype=XSD.string)))
g.add((recurso_autora_emily_bronte, biblioteca_pupo.inspiracao, Literal("Byron", datatype=XSD.string)))
g.add((recurso_autora_emily_bronte, biblioteca_pupo.inspiracao, Literal("Shakespeare", datatype=XSD.string)))
g.add((recurso_autora_emily_bronte, biblioteca_pupo.pai, Literal("Patrick Brontë", datatype=XSD.string)))
g.add((recurso_autora_emily_bronte, biblioteca_pupo.mae, Literal("Maria Branwell Brontë", datatype=XSD.string)))

# O Morro dos Ventos Uivantes (Wuthering Heights)
g.add((recurso_morro_uivantes, RDF.type, biblioteca_pupo.Livro))
g.add((recurso_morro_uivantes, biblioteca_pupo.autora, recurso_autora_emily_bronte))
g.add((recurso_morro_uivantes, biblioteca_pupo.titulo, Literal("O Morro dos Ventos Uivantes", datatype=XSD.string)))
g.add((recurso_morro_uivantes, biblioteca_pupo.publicacao, Literal("1847-12-01", datatype=XSD.date)))
g.add((recurso_morro_uivantes, biblioteca_pupo.quantidade_paginas, Literal(416, datatype=XSD.integer)))
g.add((recurso_morro_uivantes, biblioteca_pupo.editora, recurso_editora_penguin))
g.add((recurso_morro_uivantes, biblioteca_pupo.resumo, Literal("O Morro dos Ventos Uivantes é uma história de paixão, vingança e obsessão, ambientada nas charnecas da Inglaterra, envolvendo a trágica relação entre Heathcliff e Catherine Earnshaw.", datatype=XSD.string)))
g.add((recurso_morro_uivantes, biblioteca_pupo.genero_literario, URIRef(biblioteca_pupo["Romance"])))
g.add((recurso_morro_uivantes, biblioteca_pupo.genero_literario, recurso_genero_romance))


# Charlotte Brontë
#---------------------------------------------------------------------------------------------------------------------
g.add((recurso_autora_charlotte_bronte, RDF.type, biblioteca_pupo.Autora))
g.add((recurso_autora_charlotte_bronte, biblioteca_pupo.nome_completo, Literal("Charlotte Brontë", datatype=XSD.string)))
g.add((recurso_autora_charlotte_bronte, biblioteca_pupo.data_de_nascimento, Literal("1816-04-21", datatype=XSD.date)))
g.add((recurso_autora_charlotte_bronte, biblioteca_pupo.data_de_falecimento, Literal("1855-03-31", datatype=XSD.date)))
g.add((recurso_autora_charlotte_bronte, biblioteca_pupo.nacionalidade, Literal("Britânica", datatype=XSD.string)))
g.add((recurso_autora_charlotte_bronte, biblioteca_pupo.genero, Literal("Feminino", datatype=XSD.string)))
g.add((recurso_autora_charlotte_bronte, biblioteca_pupo.biografia, Literal("Charlotte Brontë foi uma romancista e poetisa britânica, mais conhecida por seu romance Jane Eyre. Ela foi uma das irmãs Brontë, cujas contribuições literárias se tornaram um marco na literatura inglesa.", datatype=XSD.string)))
g.add((recurso_autora_charlotte_bronte, biblioteca_pupo.irma, recurso_autora_emily_bronte))
g.add((recurso_autora_charlotte_bronte, biblioteca_pupo.irma, recurso_autora_anne_bronte))
g.add((recurso_autora_charlotte_bronte, biblioteca_pupo.amiga, recurso_autora_jane))
g.add((recurso_autora_charlotte_bronte, biblioteca_pupo.inspiracao, Literal("William Makepeace Thackeray", datatype=XSD.string)))
g.add((recurso_autora_charlotte_bronte, biblioteca_pupo.inspiracao, Literal("Byron", datatype=XSD.string)))
g.add((recurso_autora_charlotte_bronte, biblioteca_pupo.inspiracao, Literal("Walter Scott", datatype=XSD.string)))
g.add((recurso_autora_charlotte_bronte, biblioteca_pupo.pai, Literal("Patrick Brontë", datatype=XSD.string)))
g.add((recurso_autora_charlotte_bronte, biblioteca_pupo.mae, Literal("Maria Branwell Brontë", datatype=XSD.string)))

# Jane Eyre
g.add((recurso_jane_eyre, RDF.type, biblioteca_pupo.Livro))
g.add((recurso_jane_eyre, biblioteca_pupo.autora, recurso_autora_charlotte_bronte))
g.add((recurso_jane_eyre, biblioteca_pupo.titulo, Literal("Jane Eyre", datatype=XSD.string)))
g.add((recurso_jane_eyre, biblioteca_pupo.publicacao, Literal("1847-10-16", datatype=XSD.date)))
g.add((recurso_jane_eyre, biblioteca_pupo.quantidade_paginas, Literal(532, datatype=XSD.integer)))
g.add((recurso_jane_eyre, biblioteca_pupo.editora, recurso_editora_penguin))
g.add((recurso_jane_eyre, biblioteca_pupo.resumo, Literal("Jane Eyre é a história de uma órfã que enfrenta grandes desafios em sua vida até encontrar sua independência e amor.", datatype=XSD.string)))
g.add((recurso_jane_eyre, biblioteca_pupo.genero_literario, recurso_genero_romance))

# Villette
g.add((recurso_villette, RDF.type, biblioteca_pupo.Livro))
g.add((recurso_villette, biblioteca_pupo.autora, recurso_autora_charlotte_bronte))
g.add((recurso_villette, biblioteca_pupo.titulo, Literal("Villette", datatype=XSD.string)))
g.add((recurso_villette, biblioteca_pupo.publicacao, Literal("1853-01-26", datatype=XSD.date)))
g.add((recurso_villette, biblioteca_pupo.quantidade_paginas, Literal(573, datatype=XSD.integer)))
g.add((recurso_villette, biblioteca_pupo.editora, recurso_editora_penguin))
g.add((recurso_villette, biblioteca_pupo.resumo, Literal("Villette segue a vida de Lucy Snowe, uma jovem britânica que se muda para a cidade fictícia de Villette, onde enfrenta desafios emocionais e amorosos.", datatype=XSD.string)))
g.add((recurso_villette, biblioteca_pupo.genero_literario, recurso_genero_romance))

turtle_output = g.serialize(format="turtle")

print("#######################################################################")
print("################## Pupo bookshelf")
print("#######################################################################\n")

prefix_part, resource_part = turtle_output.split("\n\n", 1)

print(prefix_part + "\n")

custom_output = (
    f"biblioteca_pupo:13_Segundos; "
    f"biblioteca_pupo:Autora_Bel_Rodrigues; "
    f"biblioteca_pupo:Biblioteca_da_Pupo; "
    f"biblioteca_pupo:Romance;"
)

print(custom_output)

resource_lines = resource_part.splitlines()
adjusted_resource_lines = []

for line in resource_lines:
    if line.startswith(" "):  # Indicar uma indentação mais profunda
        adjusted_resource_lines.append("                                             " + line)  # Ajusta a indentação para 8 espaços
    else:
        adjusted_resource_lines.append(line)

# Exibir as triplas com indentação corrigida
print("\n".join(adjusted_resource_lines))

# Salvar o gráfico RDF como Turtle
g.serialize(destination='pupo_bookshelf.ttl', format='turtle')

# Fazer o download do arquivo Turtle gerado no Google Colab
from google.colab import files
files.download('pupo_bookshelf.ttl')
# Out:
# #######################################################################
# ################## Pupo bookshelf
# #######################################################################
#
# @prefix biblioteca_pupo: <http://biblioteca_pupo/livros#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# biblioteca_pupo:13_Segundos; biblioteca_pupo:Autora_Bel_Rodrigues; biblioteca_pupo:Biblioteca_da_Pupo; biblioteca_pupo:Romance;
# biblioteca_pupo:13_Segundos a biblioteca_pupo:Livro ;
#                                                  biblioteca_pupo:adaptado_para_filme true ;
#                                                  biblioteca_pupo:dimensoes "20.6 x 13.4 x 2 cm"^^xsd:string ;
#                                                  biblioteca_pupo:editora "Arqueiro"^^xsd:string ;
#                                                  biblioteca_pupo:email <bel_rodrigues@gmail.com> ;
# ...
